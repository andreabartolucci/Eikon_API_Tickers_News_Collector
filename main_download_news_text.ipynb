# %% [markdown]
# # Download news raw text from Eikon for a list of storyID

# %% [markdown]
# This script loads the already downloaded Eikon news storyID, connect to Eikon API and request the news raw text for each of them

# %% [markdown]
# ### Imports

# %%
import datetime
import pandas as pd
import time
import numpy as np
import dateutil
from tqdm import tqdm
import glob
import os
from IPython.display import HTML
from bs4 import BeautifulSoup
import pickle
import string
import random
import html5lib
import matplotlib
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# ### Paths setup

# %% [markdown]
# If working locally

# %%
data_path = "G:\\My Drive\\PhD\\Research\\Projects\\Portfolio Management and Sentiment views\\Data\\News\\Eikon\\"

# %% [markdown]
# If working at the Eikon's workstation

# %%
data_path = "C:\\Users\\cityu_local\\Downloads\\"

# %% [markdown]
# ### Eikon API setup

# %%
with open('Eikon_Api_Key.txt', 'r') as f:
    cookie = f.read()

# %%
import eikon as ek
ek.set_app_key(cookie)

# %% [markdown]
# ### Defining the tickers list to use

# %%
tickers = pd.read_csv("myTickerList-Eikon.csv",
                         encoding = 'utf-8',
                     index_col = 0).astype(str)
tickers
# Out:
#    ticker                                 company exchange      market_cap  \
# 0    MSFT                   Microsoft Corporation   NASDAQ  779000000000.0
# 1    AAPL                               Apple Inc   NASDAQ  744000000000.0
# 2    AMZN                           Amazoncom Inc   NASDAQ  714000000000.0
# 3   GOOGL                            Alphabet Inc   NASDAQ  712000000000.0
# 4      FB                            Facebook Inc   NASDAQ  383000000000.0
# 5     JNJ                       Johnson & Johnson     NYSE  344000000000.0
# 6     JPM                   J P Morgan Chase & Co     NYSE  321000000000.0
# 7       V                                Visa Inc     NYSE  293000000000.0
# 8     XOM                 Exxon Mobil Corporation     NYSE  291000000000.0
# 9     WMT                             Walmart Inc     NYSE  254000000000.0
# 10    PFE                              Pfizer Inc     NYSE  242000000000.0
# 11    BAC             Bank of America Corporation     NYSE  237000000000.0
# 12    UNH         UnitedHealth Group Incorporated     NYSE  233000000000.0
# 13     PG          Procter & Gamble Company (The)     NYSE  227000000000.0
# 14     KO                 Coca-Cola Company (The)     NYSE  202000000000.0
# 15     HD                    Home Depot Inc (The)     NYSE  185000000000.0
# 16    DIS               Walt Disney Company (The)     NYSE  159000000000.0
# 17    UNP               Union Pacific Corporation     NYSE   99230893092.0
# 18    HON             Honeywell International Inc     NYSE   96787269000.0
# 19    LIN                               Linde plc     NYSE   85982612516.0
# 20    NEE                      NextEra Energy Inc     NYSE   83597404902.0
# 21   SBUX                   Starbucks Corporation   NASDAQ   77103290000.0
# 22    LMT             Lockheed Martin Corporation     NYSE   75455290770.0
# 23    AMT       American Tower Corporation (REIT)     NYSE   71156409066.0
# 24    COP                          ConocoPhillips     NYSE   69074513280.0
# 25    DUK                 Duke Energy Corporation     NYSE   62833027962.0
# 26     GS           Goldman Sachs Group Inc (The)     NYSE   62644097553.0
# 27      D                     Dominion Energy Inc     NYSE   49117339863.0
# 28    OXY        Occidental Petroleum Corporation     NYSE   45777222621.0
# 29    CCI  Crown Castle International Corporation     NYSE   45633548620.0
# 30    ECL                              Ecolab Inc     NYSE   42091692407.0
# 31    PLD                            Prologis Inc     NYSE   38004726100.0
# 32    NEM              Newmont Mining Corporation     NYSE   18158387173.0
#
#             ISIN      RIC selected
# 0   US5949181045   MSFT.O        0
# 1   US0378331005   AAPL.O        1
# 2   US0231351067   AMZN.O        1
# 3   US02079K3059  GOOGL.O        1
# 4   US30303M1027     FB.O        0
# 5   US4781601046      JNJ        1
# 6   US46625H1005      JPM        1
# 7   US92826C8394        V        0
# 8   US30231G1022      XOM        1
# 9   US9311421039      WMT        1
# 10  US7170811035      PFE        0
# 11  US0605051046      BAC        0
# 12  US91324P1021      UNH        0
# 13  US7427181091       PG        0
# 14  US1912161007       KO        0
# 15  US4370761029       HD        0
# 16  US2546871060      DIS        0
# 17  US9078181081      UNP        1
# 18  US4385161066      HON        0
# 19  IE00BZ12WP82      LIN        1
# 20  US65339F1012      NEE        1
# 21  US8552441094   SBUX.O        0
# 22  US5398301094      LMT        0
# 23  US03027X1000      AMT        1
# 24  US20825C1045      COP        0
# 25  US26441C2044      DUK        0
# 26  US38141G1040       GS        0
# 27  US25746U1097        D        0
# 28  US6745991058      OXY        0
# 29  US22822V1017      CCI        0
# 30  US2788651006      ECL        0
# 31  US74340W1036      PLD        0
# 32  US6516391066      NEM        0

# %%
tickers = tickers[tickers['selected'] == '1']
tickers
# Out:
#    ticker                            company exchange      market_cap  \
# 1    AAPL                          Apple Inc   NASDAQ  744000000000.0
# 2    AMZN                      Amazoncom Inc   NASDAQ  714000000000.0
# 3   GOOGL                       Alphabet Inc   NASDAQ  712000000000.0
# 5     JNJ                  Johnson & Johnson     NYSE  344000000000.0
# 6     JPM              J P Morgan Chase & Co     NYSE  321000000000.0
# 8     XOM            Exxon Mobil Corporation     NYSE  291000000000.0
# 9     WMT                        Walmart Inc     NYSE  254000000000.0
# 17    UNP          Union Pacific Corporation     NYSE   99230893092.0
# 19    LIN                          Linde plc     NYSE   85982612516.0
# 20    NEE                 NextEra Energy Inc     NYSE   83597404902.0
# 23    AMT  American Tower Corporation (REIT)     NYSE   71156409066.0
#
#             ISIN      RIC selected
# 1   US0378331005   AAPL.O        1
# 2   US0231351067   AMZN.O        1
# 3   US02079K3059  GOOGL.O        1
# 5   US4781601046      JNJ        1
# 6   US46625H1005      JPM        1
# 8   US30231G1022      XOM        1
# 9   US9311421039      WMT        1
# 17  US9078181081      UNP        1
# 19  IE00BZ12WP82      LIN        1
# 20  US65339F1012      NEE        1
# 23  US03027X1000      AMT        1

# %%
tickers.shape
# Out:
# (11, 7)

# %% [markdown]
# ### Loading the storyID

# %%
storyId = pd.read_csv(data_path + "storyId\\storyId.csv", encoding = 'utf-8')
storyId
# Out:
#                           index                    versionCreated  \
# 0       2019-06-12 23:22:40.536  2019-06-12 23:22:40.536000+00:00
# 1       2019-06-12 23:13:47.773  2019-06-12 23:13:47.773000+00:00
# 2       2019-06-12 22:35:50.594  2019-06-12 22:35:50.594000+00:00
# 3       2019-06-12 22:21:42.000         2019-06-12 22:21:42+00:00
# 4       2019-06-12 22:21:14.000  2019-06-12 22:21:16.580000+00:00
# ...                         ...                               ...
# 164870  2020-06-01 06:00:10.000         2020-06-01 06:00:10+00:00
# 164871  2020-06-01 06:00:05.000         2020-06-01 06:00:05+00:00
# 164872  2020-06-09 23:20:42.895  2020-06-10 07:17:27.709000+00:00
# 164873  2020-06-10 14:38:20.000         2020-06-10 14:52:16+00:00
# 164874  2020-06-10 14:33:10.000         2020-06-10 14:33:10+00:00
#
#                                                      text  \
# 0       Quisitive Technology Solutions Acquires 100% S...
# 1       Reuters Insider - Cramer: Here's how to spot t...
# 2       Microsoft Corporation - Microsoft announces qu...
# 3            BRIEF-Microsoft Announces Quarterly Dividend
# 4       MICROSOFT CORP <MSFT.O> SETS QUARTERLY DIVIDEN...
# ...                                                   ...
# 164870       REG - GS ActiveBeta US  - Net Asset Value(s)
# 164871      REG - Goldman Sachs ETF  - Net Asset Value(s)
# 164872                Dow Jones Selected Stocks - June 10
# 164873  BREAKINGVIEWS-SoftBank could end up making lem...
# 164874  Goldman Sachs forms fund to address racial inj...
#
#                                              storyId sourceCode ticker  \
# 0       urn:newsml:reuters.com:20190612:nNRA8y1imv:1  NS:DATMTR   MSFT
# 1       urn:newsml:reuters.com:20190612:nRTV1KKFwz:1    NS:CNBC   MSFT
# 2       urn:newsml:reuters.com:20190612:nNDL1XwdmZ:1    NS:PUBT   MSFT
# 3       urn:newsml:reuters.com:20190612:nFWN23J0UQ:2    NS:RTRS   MSFT
# 4       urn:newsml:reuters.com:20190612:nFWN23J0UQ:2    NS:RTRS   MSFT
# ...                                              ...        ...    ...
# 164870  urn:newsml:reuters.com:20200601:nRSA4576Oa:1     NS:LSE     GS
# 164871  urn:newsml:reuters.com:20200601:nRSA4469Oa:1     NS:LSE     GS
# 164872     urn:newsml:newsroom:20200609:nNRAc0ncwa:0     NS:AAP     GS
# 164873  urn:newsml:reuters.com:20200610:nL8N2DN53P:1    NS:RTRS     GS
# 164874  urn:newsml:reuters.com:20200610:nL4N2DN338:1    NS:RTRS     GS
#
#                            date
# 0       2019-06-12 00:00:00.000
# 1       2019-06-12 00:00:00.000
# 2       2019-06-12 00:00:00.000
# 3       2019-06-12 00:00:00.000
# 4       2019-06-12 00:00:00.000
# ...                         ...
# 164870  2020-06-01 00:00:00.000
# 164871  2020-06-01 00:00:00.000
# 164872  2020-06-09 00:00:00.000
# 164873  2020-06-10 00:00:00.000
# 164874  2020-06-10 00:00:00.000
#
# [164875 rows x 7 columns]

# %%
storyId['index'] = pd.to_datetime(pd.to_datetime(storyId['index']))
storyId['versionCreated'] = pd.to_datetime(pd.to_datetime(storyId['versionCreated']))
storyId['date'] = pd.to_datetime(pd.to_datetime(storyId['date']).dt.date)
storyId
# Out:
#                          index                   versionCreated  \
# 0      2019-06-12 23:22:40.536 2019-06-12 23:22:40.536000+00:00
# 1      2019-06-12 23:13:47.773 2019-06-12 23:13:47.773000+00:00
# 2      2019-06-12 22:35:50.594 2019-06-12 22:35:50.594000+00:00
# 3      2019-06-12 22:21:42.000        2019-06-12 22:21:42+00:00
# 4      2019-06-12 22:21:14.000 2019-06-12 22:21:16.580000+00:00
# ...                        ...                              ...
# 164870 2020-06-01 06:00:10.000        2020-06-01 06:00:10+00:00
# 164871 2020-06-01 06:00:05.000        2020-06-01 06:00:05+00:00
# 164872 2020-06-09 23:20:42.895 2020-06-10 07:17:27.709000+00:00
# 164873 2020-06-10 14:38:20.000        2020-06-10 14:52:16+00:00
# 164874 2020-06-10 14:33:10.000        2020-06-10 14:33:10+00:00
#
#                                                      text  \
# 0       Quisitive Technology Solutions Acquires 100% S...
# 1       Reuters Insider - Cramer: Here's how to spot t...
# 2       Microsoft Corporation - Microsoft announces qu...
# 3            BRIEF-Microsoft Announces Quarterly Dividend
# 4       MICROSOFT CORP <MSFT.O> SETS QUARTERLY DIVIDEN...
# ...                                                   ...
# 164870       REG - GS ActiveBeta US  - Net Asset Value(s)
# 164871      REG - Goldman Sachs ETF  - Net Asset Value(s)
# 164872                Dow Jones Selected Stocks - June 10
# 164873  BREAKINGVIEWS-SoftBank could end up making lem...
# 164874  Goldman Sachs forms fund to address racial inj...
#
#                                              storyId sourceCode ticker  \
# 0       urn:newsml:reuters.com:20190612:nNRA8y1imv:1  NS:DATMTR   MSFT
# 1       urn:newsml:reuters.com:20190612:nRTV1KKFwz:1    NS:CNBC   MSFT
# 2       urn:newsml:reuters.com:20190612:nNDL1XwdmZ:1    NS:PUBT   MSFT
# 3       urn:newsml:reuters.com:20190612:nFWN23J0UQ:2    NS:RTRS   MSFT
# 4       urn:newsml:reuters.com:20190612:nFWN23J0UQ:2    NS:RTRS   MSFT
# ...                                              ...        ...    ...
# 164870  urn:newsml:reuters.com:20200601:nRSA4576Oa:1     NS:LSE     GS
# 164871  urn:newsml:reuters.com:20200601:nRSA4469Oa:1     NS:LSE     GS
# 164872     urn:newsml:newsroom:20200609:nNRAc0ncwa:0     NS:AAP     GS
# 164873  urn:newsml:reuters.com:20200610:nL8N2DN53P:1    NS:RTRS     GS
# 164874  urn:newsml:reuters.com:20200610:nL4N2DN338:1    NS:RTRS     GS
#
#              date
# 0      2019-06-12
# 1      2019-06-12
# 2      2019-06-12
# 3      2019-06-12
# 4      2019-06-12
# ...           ...
# 164870 2020-06-01
# 164871 2020-06-01
# 164872 2020-06-09
# 164873 2020-06-10
# 164874 2020-06-10
#
# [164875 rows x 7 columns]

# %%
storyId.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164875 entries, 0 to 164874
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           164875 non-null  datetime64[ns]
#  1   versionCreated  164875 non-null  datetime64[ns, UTC]
#  2   text            164875 non-null  object
#  3   storyId         164875 non-null  object
#  4   sourceCode      164875 non-null  object
#  5   ticker          164875 non-null  object
#  6   date            164875 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ### Keeping only the storyId for tickers in the tickers list

# %%
storyId['ticker'].isin(list(tickers['ticker'])).value_counts()
# Out:
# False    88623
# True     76252
# Name: ticker, dtype: int64

# %%
storyId = storyId[storyId['ticker'].isin(list(tickers['ticker']))]
storyId.reset_index(drop=True, inplace=True)
storyId
# Out:
#                         index                   versionCreated  \
# 0     2019-06-12 23:00:11.983 2019-06-12 23:00:11.983000+00:00
# 1     2019-06-12 21:57:27.059 2019-06-12 21:57:27.059000+00:00
# 2     2019-06-12 21:32:15.868 2019-06-12 21:32:15.868000+00:00
# 3     2019-06-12 21:27:02.000        2019-06-12 21:27:02+00:00
# 4     2019-06-12 20:27:24.000        2019-06-12 20:27:24+00:00
# ...                       ...                              ...
# 76247 2020-02-18 04:21:35.000        2020-02-18 20:20:37+00:00
# 76248 2020-04-30 07:20:46.999 2020-04-30 07:20:49.299000+00:00
# 76249 2020-04-30 07:03:12.228 2020-04-30 07:03:12.228000+00:00
# 76250 2020-04-30 07:00:00.000        2020-04-30 07:00:00+00:00
# 76251 2020-04-30 06:04:28.873 2020-04-30 06:04:28.873000+00:00
#
#                                                     text  \
# 0      Amazon Boosts Cashierless Initiatives With 2nd...
# 1      Reuters Insider - Facebook is sinking back int...
# 2      Reuters Insider - The question is how will tar...
# 3      Republican senator criticizes potential dual U...
# 4      Pompeo to push in India for more U.S. access t...
# ...                                                  ...
# 76247  UPDATE 9-Oil near flat; virus impact offsets L...
# 76248          Dow Jones Selected Stocks 1710 - April 30
# 76249  Apple grew by 78% in Q1 2020 in India, major c...
# 76250  EXCLUSIVE-Finance, tech firms on hiring spree ...
# 76251              Contact tracing Letters to the Editor
#
#                                              storyId sourceCode ticker  \
# 0       urn:newsml:reuters.com:20190612:nNRA8y19v4:1  NS:ZACKSC   AMZN
# 1       urn:newsml:reuters.com:20190612:nRTV1vZVFx:1    NS:CNBC   AMZN
# 2       urn:newsml:reuters.com:20190612:nRTV1cdVkS:1    NS:CNBC   AMZN
# 3       urn:newsml:reuters.com:20190612:nL2N23J1K6:3    NS:RTRS   AMZN
# 4       urn:newsml:reuters.com:20190612:nL2N23J1FG:5    NS:RTRS   AMZN
# ...                                              ...        ...    ...
# 76247  urn:newsml:reuters.com:20200218:nL4N2AI139:16    NS:RTRS   AAPL
# 76248      urn:newsml:newsroom:20200430:nNRAbo9mnf:0     NS:AAP   AAPL
# 76249   urn:newsml:reuters.com:20200430:nNRAbo9gve:1  NS:HINDUT   AAPL
# 76250   urn:newsml:reuters.com:20200430:nL4N2CH2DP:1    NS:RTRS   AAPL
# 76251   urn:newsml:reuters.com:20200430:nNRAbo8o1l:1  NS:TELGPH   AAPL
#
#             date
# 0     2019-06-12
# 1     2019-06-12
# 2     2019-06-12
# 3     2019-06-12
# 4     2019-06-12
# ...          ...
# 76247 2020-02-18
# 76248 2020-04-30
# 76249 2020-04-30
# 76250 2020-04-30
# 76251 2020-04-30
#
# [76252 rows x 7 columns]

# %%
storyId.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76252 entries, 0 to 76251
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           76252 non-null  datetime64[ns]
#  1   versionCreated  76252 non-null  datetime64[ns, UTC]
#  2   text            76252 non-null  object
#  3   storyId         76252 non-null  object
#  4   sourceCode      76252 non-null  object
#  5   ticker          76252 non-null  object
#  6   date            76252 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), object(4)
# memory usage: 4.1+ MB

# %%
pd.concat([storyId.groupby(['ticker']).size(), storyId.groupby(['ticker']).size()/365], axis=1)
# Out:
#             0          1
# ticker
# AAPL    12289  33.668493
# AMT       625   1.712329
# AMZN    15754  43.161644
# GOOGL    8821  24.167123
# JNJ      4233  11.597260
# JPM     20737  56.813699
# LIN      1199   3.284932
# NEE      1087   2.978082
# UNP       985   2.698630
# WMT      6020  16.493151
# XOM      4502  12.334247

# %% [markdown]
# ### Deleting the dates that do not overlap for the 5 tickers and 28 tickers samples

# %% [markdown]
# For the initial 5 tickers we collected the storyId starting from 2019-6-9, however for the remaining 28 we started from 2019-6-12. The end date for the initial 5 tickers was 2019-6-12, for the remaining 28 is 2020-6-16.<br>The overlaping dates therefore are from 2019-6-12 to 2020-6-12

# %%
start_date = datetime.datetime(2019, 6, 12)
end_date = datetime.datetime(2020, 6, 12)

# %%
storyId[(storyId['date'] < start_date)].shape[0]
# Out:
# 85

# %%
storyId[(storyId['date'] > end_date)].shape[0]
# Out:
# 386

# %%
storyId = storyId[(storyId['date'] <= end_date)]
storyId = storyId[(storyId['date'] >= start_date)]
storyId
# Out:
#                         index                   versionCreated  \
# 0     2019-06-12 23:00:11.983 2019-06-12 23:00:11.983000+00:00
# 1     2019-06-12 21:57:27.059 2019-06-12 21:57:27.059000+00:00
# 2     2019-06-12 21:32:15.868 2019-06-12 21:32:15.868000+00:00
# 3     2019-06-12 21:27:02.000        2019-06-12 21:27:02+00:00
# 4     2019-06-12 20:27:24.000        2019-06-12 20:27:24+00:00
# ...                       ...                              ...
# 76247 2020-02-18 04:21:35.000        2020-02-18 20:20:37+00:00
# 76248 2020-04-30 07:20:46.999 2020-04-30 07:20:49.299000+00:00
# 76249 2020-04-30 07:03:12.228 2020-04-30 07:03:12.228000+00:00
# 76250 2020-04-30 07:00:00.000        2020-04-30 07:00:00+00:00
# 76251 2020-04-30 06:04:28.873 2020-04-30 06:04:28.873000+00:00
#
#                                                     text  \
# 0      Amazon Boosts Cashierless Initiatives With 2nd...
# 1      Reuters Insider - Facebook is sinking back int...
# 2      Reuters Insider - The question is how will tar...
# 3      Republican senator criticizes potential dual U...
# 4      Pompeo to push in India for more U.S. access t...
# ...                                                  ...
# 76247  UPDATE 9-Oil near flat; virus impact offsets L...
# 76248          Dow Jones Selected Stocks 1710 - April 30
# 76249  Apple grew by 78% in Q1 2020 in India, major c...
# 76250  EXCLUSIVE-Finance, tech firms on hiring spree ...
# 76251              Contact tracing Letters to the Editor
#
#                                              storyId sourceCode ticker  \
# 0       urn:newsml:reuters.com:20190612:nNRA8y19v4:1  NS:ZACKSC   AMZN
# 1       urn:newsml:reuters.com:20190612:nRTV1vZVFx:1    NS:CNBC   AMZN
# 2       urn:newsml:reuters.com:20190612:nRTV1cdVkS:1    NS:CNBC   AMZN
# 3       urn:newsml:reuters.com:20190612:nL2N23J1K6:3    NS:RTRS   AMZN
# 4       urn:newsml:reuters.com:20190612:nL2N23J1FG:5    NS:RTRS   AMZN
# ...                                              ...        ...    ...
# 76247  urn:newsml:reuters.com:20200218:nL4N2AI139:16    NS:RTRS   AAPL
# 76248      urn:newsml:newsroom:20200430:nNRAbo9mnf:0     NS:AAP   AAPL
# 76249   urn:newsml:reuters.com:20200430:nNRAbo9gve:1  NS:HINDUT   AAPL
# 76250   urn:newsml:reuters.com:20200430:nL4N2CH2DP:1    NS:RTRS   AAPL
# 76251   urn:newsml:reuters.com:20200430:nNRAbo8o1l:1  NS:TELGPH   AAPL
#
#             date
# 0     2019-06-12
# 1     2019-06-12
# 2     2019-06-12
# 3     2019-06-12
# 4     2019-06-12
# ...          ...
# 76247 2020-02-18
# 76248 2020-04-30
# 76249 2020-04-30
# 76250 2020-04-30
# 76251 2020-04-30
#
# [75781 rows x 7 columns]

# %%
storyId['date'].describe()
# Out:
# count                   75781
# unique                    367
# top       2019-12-03 00:00:00
# freq                      794
# first     2019-06-12 00:00:00
# last      2020-06-12 00:00:00
# Name: date, dtype: object

# %% [markdown]
# ### Creating a list of dates to iter over

# %%
date_list = pd.DataFrame((pd.to_datetime(storyId['date'].dt.date.unique())))
date_list.columns = ['date']
date_list.sort_values(by=['date'])
# Out:
#           date
# 0   2019-06-12
# 1   2019-06-13
# 2   2019-06-14
# 3   2019-06-15
# 4   2019-06-16
# ..         ...
# 362 2020-06-08
# 363 2020-06-09
# 364 2020-06-10
# 365 2020-06-11
# 366 2020-06-12
#
# [367 rows x 1 columns]

# %% [markdown]
# 2020 is leap year, plus 1 date (2020-6-12) which is the first of the next solar solar year

# %%
date_list = date_list[date_list['date'] > datetime.datetime(2020,2,2)]
date_list
# Out:
#           date
# 236 2020-02-03
# 237 2020-02-04
# 238 2020-02-05
# 239 2020-02-06
# 240 2020-02-07
# ..         ...
# 362 2020-06-08
# 363 2020-06-09
# 364 2020-06-10
# 365 2020-06-11
# 366 2020-06-12
#
# [131 rows x 1 columns]

# %%
date_list.describe()
# Out:
#                        date
# count                   131
# unique                  131
# top     2020-03-13 00:00:00
# freq                      1
# first   2020-02-03 00:00:00
# last    2020-06-12 00:00:00

# %% [markdown]
# ### Creating date groups in storyId

# %%
date_group = storyId.groupby('date')

# %% [markdown]
# ### Collecting the news raw text

# %%
j = 0
#iterate on the dates
for date in tqdm(date_list.itertuples(), desc = 'dates list'):
    #initialize the  data frame for the current iteration date
    news_text = pd.DataFrame(columns = ['storyId', 'story'])    
    #assign the current iteration date to a variable
    date = date.date.strftime('%Y-%m-%d')
    #assign the data frame that contains the current iteration date to a variable
    storyId_in_date = date_group.get_group(date)['storyId']
    print('########################## start collecting {} news for the date {}'.format(storyId_in_date.shape[0], date))     
    #iterate on the storyId for the current iteration date
    
    #check if API requests limit number has been hit
    if (j + storyId_in_date.shape[0]) > 10000:
        break
        print('hit limit of {} API requests'.format(j))
        
    for i, storyId in tqdm(enumerate(storyId_in_date), desc = 'storyID Loop'):
        #print('{} {}'.format(i, storyId))
        j += 1
        if 'html' in locals():
            del html
        try:
            html = ek.get_news_story(storyId)
        except:
            print('!!!!!!!!!!!!!!!!!!!!! story {} story-date {} story Id: {} NOT FOUND'.format(j, i, storyId))
            #append the current iteration story to news_text, write np.nan if the story is not found
            news_text = pd.concat([news_text, pd.DataFrame([{'storyId': storyId,'story': np.nan}])]) 
            continue
        #get the text part parsing the html   
        story = BeautifulSoup(html, 'html5lib').get_text() 
        print('story {} story-date {} story Id: {} story: {}'.format(j, i, storyId, story[0:50]))
        #append the current iteration story to news_text
        news_text = pd.concat([news_text, pd.DataFrame([{'storyId': storyId,'story': story}])])   
        
    #write on a file the stories collected for the current iteration date
    #pickle.dump(news_text, open(data_path + '\\story\\{}.pkl'.format(date), 'wb'))
    news_text.to_csv(data_path + 'story\\{}.csv'.format(date), header=False, index=False,encoding = 'utf-8')
